# %% [markdown]
# # Exercício 3 - Algotrading
#
# **Antonio Fuziy**

# %% [markdown]
# ___
#
# ### Lista: Exercício 3 - 16/Mai até 9h30
#
# * Modificar a ideia 1 da aula de hoje para simular pares de até 3 ações americanas correlacionadas.
# * Selecionar entre 1 ano e 2 anos de dados
# * Precisa ajustar as quantidades para que tenham o mesmo valor financeiro. As quantidades serão inteiros múltiplos de 1.
# * Entregar um **PDF** com o código e o gráfico da simulação do resultado
# * Prazo: 16/Mai até 9h30 via Blackboard (Após esse prazo será considerado atrasado)
# * Estritamente individual

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from statsmodels.tsa.stattools import coint
import statsmodels.tsa.stattools as st
import time
from datetime import datetime
import random
import pandas.testing as tm
from statsmodels.tsa.stattools import adfuller
import yahoofinancials as yf

from backtesting_v2_1 import TradingSystem, MarketData, Order, Strategy, Event, evaluateHist

# %%
tickers = ['NKE', "NKE.DE", "BPAC11.SA", "XP"]

start_date = '2021-05-10'
end_date =  '2022-05-10'

for ticker in tickers:
    data = yf.YahooFinancials(ticker).get_historical_price_data(start_date, end_date, 'daily')

    # Ler os dados do JSON
    raw = pd.DataFrame(data[ticker]['prices']).dropna()
    # Converter a data para o tipo correto datetime
    raw['formatted_date'] = pd.to_datetime(raw['formatted_date'])
    # Indica a data como o índice de cada linha
    raw = raw.set_index('formatted_date')
    # Removendo as colunas que não interessam
    df = raw.iloc[:,1:]

    # Acertando a ordem das colunas
    df = df.reindex(columns=['open', 'high', 'low', 'close', 'adjclose', 'volume'])
    # Salvando o CSV
    df.to_csv('{}.csv'.format(ticker))

# %%
nike = pd.read_csv('NKE.csv')
nike_de = pd.read_csv('NKE.DE.csv')
btg = pd.read_csv("BPAC11.SA.csv")
xp = pd.read_csv("XP.csv")

# %%
nike.set_index('formatted_date')
nike_de.set_index('formatted_date')
btg.set_index('formatted_date')
xp.set_index('formatted_date')
# Out:
#                      open       high        low      close   adjclose  \
# formatted_date
# 2021-05-10      44.689999  44.700001  42.509998  42.630001  42.630001
# 2021-05-11      40.849998  44.450001  40.799999  43.950001  43.950001
# 2021-05-12      43.450001  43.680000  41.320000  41.439999  41.439999
# 2021-05-13      42.389999  42.549999  40.369999  41.090000  41.090000
# 2021-05-14      41.840000  43.130001  41.459999  42.900002  42.900002
# ...                   ...        ...        ...        ...        ...
# 2022-05-03      24.270000  24.299999  23.309999  23.590000  23.590000
# 2022-05-04      21.660000  22.070000  19.205000  21.830000  21.830000
# 2022-05-05      21.150000  21.670000  20.930000  21.430000  21.430000
# 2022-05-06      21.190001  21.350000  20.129999  20.139999  20.139999
# 2022-05-09      19.650000  20.160000  18.469999  18.930000  18.930000
#
#                   volume
# formatted_date
# 2021-05-10       1070200
# 2021-05-11       1514500
# ...

# %%
df_join_ = nike.join(nike_de, how='inner', lsuffix='_nike', rsuffix='_nike_de')

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.plot(df_join_.adjclose_nike);
plt.plot(df_join_.adjclose_nike_de);

plt.subplot(1, 2, 2)
plt.scatter(df_join_.adjclose_nike, df_join_.adjclose_nike_de);
plt.show()

# %%
spearmanr(df_join_.adjclose_nike, df_join_.adjclose_nike_de)
# Out:
# SignificanceResult(statistic=0.9229141703704629, pvalue=4.88072864912119e-106)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
ret_nike = df_join_.adjclose_nike/df_join_.adjclose_nike[0]-1
plt.plot(ret_nike);
ret_nike_de = df_join_.adjclose_nike_de/df_join_.adjclose_nike_de[0]-1
plt.plot(ret_nike_de);

plt.subplot(1, 3, 2)
plt.plot(ret_nike-ret_nike_de);

plt.subplot(1, 3, 3)
df_join_['diff'] = df_join_.adjclose_nike.pct_change()-df_join_.adjclose_nike_de.pct_change()
df_join_ = df_join_.dropna()
plt.plot(df_join_['diff']);

plt.show()

# %%
adf, pvalue, *_ = adfuller(df_join_['diff'])
print(pvalue)
# Out:
# 1.543108256828489e-14

# %%
df_join_['diff'].describe()
# Out:
# count    252.000000
# mean      -0.000814
# std        0.023365
# min       -0.074246
# 25%       -0.013412
# 50%       -0.000347
# 75%        0.010273
# max        0.094375
# Name: diff, dtype: float64

# %%
df_join_diff = pd.DataFrame({'formatted_date': df_join_['formatted_date_nike'],
                    'open': df_join_['open_nike'],
                    'high': df_join_['high_nike'],
                    'low': df_join_['low_nike'],
                    'close': df_join_['close_nike'],
                    'adjclose': df_join_['diff'],
                    'volume': 0,
                   })
df_join_diff = df_join_diff.set_index('formatted_date')
df_join_diff
# Out:
#                       open        high         low       close  adjclose  \
# formatted_date
# 2021-05-11      138.380005  138.380005  135.009995  137.119995  0.017592
# 2021-05-12      135.419998  136.820007  133.339996  133.389999 -0.024531
# 2021-05-13      133.699997  135.029999  132.490005  133.610001  0.010399
# 2021-05-14      134.339996  136.679993  134.050003  135.929993  0.012140
# 2021-05-17      136.330002  137.070007  135.500000  136.410004  0.002456
# ...                    ...         ...         ...         ...       ...
# 2022-05-03      125.019997  125.760002  120.220001  122.860001 -0.054051
# 2022-05-04      122.540001  126.199997  120.080002  126.059998  0.008128
# 2022-05-05      124.110001  124.750000  116.519997  118.629997 -0.039345
# 2022-05-06      113.739998  115.900002  110.660004  114.489998 -0.019824
# 2022-05-09      112.970001  114.430000  110.589996  111.209999 -0.009044
#
#                 volume
# formatted_date
# 2021-05-11           0
# ...

# %%
df_join_diff.to_csv('df_join_diff.csv')

# %%
class LongShort(Strategy):
    
    def __init__(self, uband, lband):
        self.prices = []
        self.indicator = []
        
        self.side = 0
        
        self.uband = uband
        self.lband = lband
        
    def receive(self, event):
        
        orders = []
        if event.instrument == 'df_join_diff':

            price = event.price[3] # Captura o spread

            # Montando a série de preços:
            self.prices.append(price)

            if price > self.uband:
                signal = -1 # Sell PETR3, buy PETR4
            elif price < self.lband:
                signal = 1 # Buy PETR3, sell PETR4

            if self.side != signal:
                
                # Vamos user o mesmo tamanho porque eles tem preços semelhantes!
                # Mas não é o ideal!
                
                
                if self.side > 0: # Se está comprado em PETR3, vende PETR3 e compra PETR4
                    self.submit(self.id, Order('NKE', Order.S, 50*self.side, 0))
                    self.submit(self.id, Order('NKE.DE', Order.B, 50*self.side, 0))
                elif self.side < 0: # Senão faz o inverso
                    self.submit(self.id, Order('NKE', Order.B, 50*self.side, 0))
                    self.submit(self.id, Order('NKE.DE', Order.S, 50*self.side, 0))
                
                if signal > 0: # Se quer comprar PETR3, compra PETR3 e vende PETR4
                    self.submit(self.id, Order('NKE', Order.B, 50*signal, 0))
                    self.submit(self.id, Order('NKE.DE', Order.S, 50*signal, 0))
                elif signal < 0: # Senão faz o inverso
                    self.submit(self.id, Order('NKE', Order.S, 50*signal, 0))
                    self.submit(self.id, Order('NKE.DE', Order.B, 50*signal, 0))

                self.side = signal
        
        return orders
    
    
model = LongShort(metrics[4], metrics[6])
print(evaluateHist(model, {'NKE': 'NKE.csv', 'NKE.DE': 'NKE.DE.csv', 'df_join_diff': 'df_join_diff.csv'}))
# Out:
# Gross Profit: $4887.47
# Gross Loss: $-2675.29
# Gross Total: $2212.18
#
# Number of trades: 97
# Hitting Ratio: 56.70%
# Number of profit trades: 55
# Number of loss trades: 41
# Average number of events per trade: 2.65
#
# Max win trade: $372.28
# Avg win trade: $88.86
# Max loss trade: $-249.98
# Avg loss trade: $-65.25
# Avg all trades: $22.81
# Win/Loss ratio: 1.36
#
# Max Profit: $476.01
# Max Profit High/Low: $517.97
# Max Drawdown: $-1103.36
# Max Drawdown High/Low: $-1121.32
#
# Max Allocation: $8610.98
# Avg Allocation: $7351.78
# Max Cash Required (margin): $8610.98
#
# Gross Total: $2212.18
# Total Fees: $38.80
# Total Taxes: $746.45
# Net Total: $1426.93
#
# Gross Return: 31.14%
# Average Return: 0.32%
# Net Return: 20.15%
# Net Return Avg Alocation: 19.41%
#
# Number of days: 259
# Initial Capital: $10000.00
# Risk Free Rate: 13.75% yearly/0.0511% daily
# Total Carry: $453.22
# Net Total + Carry: $1880.15
# Net Return Capital: 18.80%
# Net Return Capital Yearly: 18.25%
