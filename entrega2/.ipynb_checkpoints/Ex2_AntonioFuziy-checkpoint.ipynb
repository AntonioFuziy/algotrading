# %% [markdown]
# ___
#
# # Exercício 2 - Algotrading
#
# **Antonio Fuziy**

# %% [markdown]
# ### Lista: Exercício 2 - 28/Mar até 13h30
#
# * Utilizar os dados de PETR3 **intradia** no Blackboard
# * Usar o modelo de simulação acima usando a biblioteca backtesting
# * Adaptar a estratégia Martingale:
#   * Diminuir a posição para 1 quando o preço for 3% acima do preço médio
#   * Quando fizer o stop gain, estabeleça o novo preço médio como o preço de venda
#   * Se o preço cair, deixe a estratégia agir, dobrando a posição
#   * Interprete o resultado
# * Montar um notebook próprio, não reutilizar o da aula.
# * Entregar um **PDF** com o código da estratégia
# * Prazo: 28/Mar até 13h30 via Blackboard (Após esse prazo será considerado atrasado)
# * Estritamente individual

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import datetime
import random
from backtesting import evaluateHist, evaluateIntr, Strategy, Order
import yahoofinancials as yf
import os

# %%
file = './PETR4-Dataset/PETR4-2012-04-05.csv'
df = pd.read_csv(file, sep=';', decimal=',')
df.head()
# Out:
#                  Dates   Open  Close   High    Low
# 0  05/04/2012 10:03:00  21.82  21.88  21.88  21.82
# 1  05/04/2012 10:04:00  21.88  21.90  21.95  21.88
# 2  05/04/2012 10:05:00  21.90  21.92  21.92  21.90
# 3  05/04/2012 10:06:00  21.92  21.94  21.95  21.91
# 4  05/04/2012 10:07:00  21.94  21.95  21.95  21.92

# %%
class Martingale(Strategy):
    def __init__(self):
        self.trades = []
        self.size = 0
        self.average = 0

    def receive(self, event):
        price = event.price[3]

        if self.size == 0:
            self.submit(self._id, Order(event.instrument, Order.B, 1, 0))
            self.size = 1
            self.average = price
            print("Start: Price: {0} | Average: {1} | Position Quantity: {2}".format(price, self.average, self.size))

        #se cair 0.5%, dobra a posição
        elif (price/self.average - 1) <= -0.005:
            self.submit(self._id, Order(event.instrument,  Order.B, self.size, 0))
            self.size *= 2
            self.average += price
            self.average /= 2
            print("Double Position | Price:{0} | Average:{1} | Position Quantity:{2}".format(price, self.average, self.size))
            
        #se subir 0.5%, vende tudo até sobrar um
        elif (price/self.average - 1) >= 0.005 and self.size > 1:
            self.submit(self._id, Order(event.instrument, Order.S, (self.size-1), 0))
            self.size = 1
            self.average = price
            print("Sell everything and hold one | Price:{0} | Average:{1} | Position Quantity:{2}".format(price, self.average, self.size))
            
print(
    evaluateIntr(
        Martingale(), 
        {
            'PETR4': file
        }
    )
)
# Out:
# Start: Price: 21.88 | Average: 21.88 | Position Quantity: 1
# Double Position | Price:21.74 | Average:21.81 | Position Quantity:2
# Double Position | Price:21.69 | Average:21.75 | Position Quantity:4
# Sell everything and hold one | Price:21.88 | Average:21.88 | Position Quantity:1
# Number of trades: 1
# Gross P&L: 0.78
# Gross Average Return: 0.89%
# Tax: 0.04
# Fee: 0.00
# Net P&L: 0.74
# Hitting ratio: 100.00%
# Max Trade P&L: 0.78
# Min Trade P&L: 0.78

# %% [markdown]
# ___
#
# Observando o resultado de um dia utilizando a estratégia de Martingale, verifica-se que o algoritmo realizou apenas um trade, obtendo um retorno de 0.89%. Ao observar o Gross P&L é possível afirmar que o retorno foi positivo, uma vez que o Gross P&L foi de 0.78, significando que a diferença entre lucro e prejuízo foi positiva. Essa estratégia de Martingale é considerada arriscada, pois a cada vez que o valor do ativo cai 0.5% do valor comprado, a posição é dobrada, gerando uma exposição de caixa muito grande. Portanto, essa estratégia cabe para casos em que o caixa é muito grande ou quase infinito. No caso do dia 05 de abril de 2012, o algoritmo obteve lucro, porém apenas um trade foi realizado, logo seria interessante observar o retorno em um longo prazo para verificar a efetividade da estratégia de Martingale.

# %% [markdown]
# #### Um teste para alguns outros dias da base de dados

# %%
all_csvs = os.listdir("PETR4-Dataset")
for csv_index in range(0, len(all_csvs), 20):
    csv = all_csvs[csv_index]
    print("========================================================================")
    print("")
    print(
        evaluateIntr(
                Martingale(), {
                file: f'PETR4-Dataset/{csv}'
            }
        )
    )
# Out:
# ========================================================================
#
# Start: Price: 21.33 | Average: 21.33 | Position Quantity: 1
# Double Position | Price:21.21 | Average:21.27 | Position Quantity:2
# Double Position | Price:21.15 | Average:21.21 | Position Quantity:4
# Sell everything and hold one | Price:21.35 | Average:21.35 | Position Quantity:1
# Number of trades: 1
# Gross P&L: 0.69
# Gross Average Return: 0.81%
# Tax: 0.04
# Fee: 0.00
# Net P&L: 0.65
# Hitting ratio: 100.00%
# Max Trade P&L: 0.69
# Min Trade P&L: 0.69
#
# ========================================================================
#
# Start: Price: 19.1 | Average: 19.1 | Position Quantity: 1
# Double Position | Price:19.0 | Average:19.05 | Position Quantity:2
# Sell everything and hold one | Price:19.19 | Average:19.19 | Position Quantity:1
# Double Position | Price:19.09 | Average:19.14 | Position Quantity:2
# Sell everything and hold one | Price:19.25 | Average:19.25 | Position Quantity:1
# Number of trades: 1
# Gross P&L: 0.55
# Gross Average Return: 0.96%
# Tax: 0.03
# Fee: 0.00
# Net P&L: 0.52
# Hitting ratio: 100.00%
# Max Trade P&L: 0.55
# Min Trade P&L: 0.55
#
# ========================================================================
#
# Start: Price: 20.05 | Average: 20.05 | Position Quantity: 1
# Double Position | Price:19.89 | Average:19.97 | Position Quantity:2
# Double Position | Price:19.86 | Average:19.915 | Position Quantity:4
# Double Position | Price:19.81 | Average:19.862499999999997 | Position Quantity:8
# Sell everything and hold one | Price:20.0 | Average:20.0 | Position Quantity:1
# Number of trades: 1
# Gross P&L: 1.29
# Gross Average Return: 0.81%
# Tax: 0.08
# Fee: 0.00
# Net P&L: 1.21
# Hitting ratio: 100.00%
# Max Trade P&L: 1.29
# Min Trade P&L: 1.29
#
# ========================================================================
#
# Start: Price: 20.3 | Average: 20.3 | Position Quantity: 1
# Double Position | Price:20.18 | Average:20.240000000000002 | Position Quantity:2
# Double Position | Price:20.13 | Average:20.185000000000002 | Position Quantity:4
# Sell everything and hold one | Price:20.31 | Average:20.31 | Position Quantity:1
# Double Position | Price:20.2 | Average:20.255 | Position Quantity:2
# Double Position | Price:20.15 | Average:20.2025 | Position Quantity:4
# Double Position | Price:20.09 | Average:20.146250000000002 | Position Quantity:8
# Double Position | Price:20.01 | Average:20.078125 | Position Quantity:16
# Double Position | Price:19.96 | Average:20.0190625 | Position Quantity:32
# Double Position | Price:19.91 | Average:19.96453125 | Position Quantity:64
# Double Position | Price:19.86 | Average:19.912265625 | Position Quantity:128
# Double Position | Price:19.81 | Average:19.8611328125 | Position Quantity:256
# Double Position | Price:19.74 | Average:19.80056640625 | Position Quantity:512
# Sell everything and hold one | Price:19.9 | Average:19.9 | Position Quantity:1
# Double Position | Price:19.8 | Average:19.85 | Position Quantity:2
# Double Position | Price:19.72 | Average:19.785 | Position Quantity:4
# Number of trades: 1
# Gross P&L: 51.47
# Gross Average Return: 0.50%
# Tax: 4.94
# Fee: 0.00
# Net P&L: 46.53
# Hitting ratio: 100.00%
# Max Trade P&L: 51.47
# Min Trade P&L: 51.47
#
# ========================================================================
#
# Start: Price: 19.45 | Average: 19.45 | Position Quantity: 1
# Double Position | Price:19.35 | Average:19.4 | Position Quantity:2
# Double Position | Price:19.27 | Average:19.335 | Position Quantity:4
# Sell everything and hold one | Price:19.44 | Average:19.44 | Position Quantity:1
# Double Position | Price:19.33 | Average:19.384999999999998 | Position Quantity:2
# Double Position | Price:19.16 | Average:19.2725 | Position Quantity:4
# Double Position | Price:19.16 | Average:19.216250000000002 | Position Quantity:8
# Double Position | Price:19.07 | Average:19.143125 | Position Quantity:16
# Double Position | Price:19.04 | Average:19.091562500000002 | Position Quantity:32
# Double Position | Price:18.98 | Average:19.03578125 | Position Quantity:64
# Double Position | Price:18.91 | Average:18.972890624999998 | Position Quantity:128
# Double Position | Price:18.87 | Average:18.921445312499998 | Position Quantity:256
# Double Position | Price:18.75 | Average:18.83572265625 | Position Quantity:512
# Double Position | Price:18.68 | Average:18.757861328125 | Position Quantity:1024
# Sell everything and hold one | Price:18.89 | Average:18.89 | Position Quantity:1
# Double Position | Price:18.76 | Average:18.825000000000003 | Position Quantity:2
# Double Position | Price:18.73 | Average:18.777500000000003 | Position Quantity:4
# Double Position | Price:18.67 | Average:18.723750000000003 | Position Quantity:8
# Double Position | Price:18.63 | Average:18.676875000000003 | Position Quantity:16
# Double Position | Price:18.58 | Average:18.6284375 | Position Quantity:32
# Sell everything and hold one | Price:18.74 | Average:18.74 | Position Quantity:1
# Number of trades: 1
# Gross P&L: 139.36
# Gross Average Return: 0.70%
# Tax: 9.56
# Fee: 0.00
# Net P&L: 129.80
# Hitting ratio: 100.00%
# Max Trade P&L: 139.36
# Min Trade P&L: 139.36
#
# ========================================================================
#
# Start: Price: 20.95 | Average: 20.95 | Position Quantity: 1
# Double Position | Price:20.82 | Average:20.884999999999998 | Position Quantity:2
# Double Position | Price:20.77 | Average:20.8275 | Position Quantity:4
# Double Position | Price:20.72 | Average:20.77375 | Position Quantity:8
# Sell everything and hold one | Price:20.88 | Average:20.88 | Position Quantity:1
# Number of trades: 1
# Gross P&L: 0.97
# Gross Average Return: 0.58%
# Tax: 0.08
# Fee: 0.00
# Net P&L: 0.89
# Hitting ratio: 100.00%
# Max Trade P&L: 0.97
# Min Trade P&L: 0.97
